# %% [markdown]
# <div style="background-color:#1e1e2e; padding:20px; border-radius:10px; color:#cdd6f4; font-family:sans-serif;">
#   <h1 style="color:#89b4fa; margin-top:0;">Detección de Anomalías y Fraude Financiero</h1>
#   <p style="font-size:1.1em; color:#bac2de;">Análisis  de patrones transaccionales basado en el monto operativo y la hora de ejecución.</p>
#   <hr style="border:0; border-top:1px solid #45475a;">
#   <span style="background-color:#a6e3a1; color:#11111b; padding:4px 8px; border-radius:5px; font-weight:bold; font-size:0.85em;">Python 3.x</span>
#   <span style="background-color:#f9e2af; color:#11111b; padding:4px 8px; border-radius:5px; font-weight:bold; font-size:0.85em;">Pandas & Matplotlib</span>
#   <span style="background-color:#89b4fa; color:#11111b; padding:4px 8px; border-radius:5px; font-weight:bold; font-size:0.85em;">Simulación Monte Carlo</span>
# </div>
#
# ---
#
# ### 1. Resumen Ejecutivo
# Este notebook simula el comportamiento de **300 transacciones electrónicas** mediante reglas de negocio probabilísticas. El objetivo es identificar zonas de riesgo operacional agrupando dos variables clave:
#
# | Variable | Tipo de Dato | Descripción |
# | :--- | :--- | :--- |
# | **`hora`** | Entero ($0 - 23$) | Hora en que se ejecutó la operación. |
# | **`monto`** | Flotante ($S/$) | Importe monetario de la transacción. |
# | **`es_fraude`** | Binario ($0 / 1$) | Indicador de anomalía ($0$: Legítimo, $1$: Fraude). |

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Semilla de reproducibilidad
np.random.seed(42)
n = 300

# Variables independientes
hora = np.random.randint(0, 24, n)
monto = np.random.exponential(scale=150, size=n) + 10

# Modelo probabilístico de fraude
prob_fraude = 0.03 + 0.35 * ((hora <= 5) | (hora >= 23)) + 0.25 * (monto > 400)
prob_fraude = np.clip(prob_fraude, 0, 0.9)

# Mapeo de eventos
es_fraude = (np.random.rand(n) < prob_fraude).astype(int)
transacciones = pd.DataFrame({"hora": hora, "monto": monto, "es_fraude": es_fraude})

# Vista previa de datos
transacciones.head(8)lt
# Out:
#   Cell In[1], line 22
#     transacciones.head(8)lt
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# <div style="background-color:#2a2a3c; padding:15px; border-left:5px solid #f9e2af; border-radius:4px; color:#cdd6f4;">
#   <strong style="color:#f9e2af;">Modelo Matematico de Probabilidad</strong><br>
#   La probabilidad individual de fraude $P(F)$ para cada transacción se rige bajo la siguiente formula parametrizada:
# </div>
#
# $$P(F) = \min\left(0.9, \; 0.03 + 0.35 \cdot \mathbb{I}_{\text{madrugada}} + 0.25 \cdot \mathbb{I}_{\text{monto} > 400}\right)$$
#
# * **Madrugada:** Horarios comprendidos entre las 23:00 h y las 05:00 h.
# * **Monto Crítico:** Operaciones superiores a **S/ 400.00**.

# %%
# Paleta de colores minimalista
colores = {0: "#0ca30c", 1: "#d03b3b"}
etiquetas = {0: "Legítima", 1: "Fraude"}

# Creación de figura
fig, ax = plt.subplots(figsize=(10, 5.5), facecolor="#fcfcfb")
ax.set_facecolor("#fcfcfb")

# Graficación por categoría
for valor in [0, 1]:
    subset = transacciones[transacciones["es_fraude"] == valor]
    ax.scatter(
        subset["hora"], subset["monto"],
        s=75, alpha=0.8,
        c=colores[valor],
        edgecolors="white", linewidths=0.7,
        label=etiquetas[valor]
    )

# Formato visual
ax.set_title("Distribución de Transacciones por Hora y Monto", fontsize=14, color="#0b0b0b", pad=15, fontweight="bold")
ax.set_xlabel("Hora del día (Formato 24h)", fontsize=11, color="#52514e")
ax.set_ylabel("Monto Transaccionado (S/)", fontsize=11, color="#52514e")
ax.set_xticks(range(0, 24, 2))
ax.grid(True, color="#e1e0d9", linestyle="--", linewidth=0.6)
ax.spines[["top", "right"]].set_visible(False)
ax.legend(title="Categoría", frameon=True, facecolor="#ffffff", edgecolor="none", loc="upper right")

plt.tight_layout()
plt.show()

# Resumen numérico post-gráfico
total = len(transacciones)
fraudes = transacciones["es_fraude"].sum()
porcentaje = (fraudes / total) * 100

print(f"Resumen del Dataset | Total: {total} | Fraudes: {fraudes} ({porcentaje:.1f}%)")

# %%
<div style="background-color:#1e293b; padding:15px; border-radius:8px; color:#e2e8f0;">
  <h3 style="color:#38bdf8; margin-top:0;">Conclusiones del Análisis</h3>
  <ul>
    <li><b>Concentración de riesgo:</b> La mayoría de los puntos rojos (<span style="color:#f87171;">Fraude</span>) se agrupan en las primeras horas de la madrugada y en importes elevados.</li>
    <li><b>Falsos Positivos:</b> El modelo probabilístico contempla un 3% base, representando anomalías diurnas de bajo monto.</li>
    <li><b>Recomendación de seguridad:</b> Implementar un segundo factor de autenticación (2FA) obligatorio para cualquier transacción mayor a S/ 400 efectuada entre las 23:00 h y 05:00 h.</li>
  </ul>
</div>
